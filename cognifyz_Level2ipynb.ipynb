# %% [markdown]
# **Author: Vishal Khatik**

# %% [markdown]
# **Domain: Data Science**

# %% [markdown]
# **Organization: Cognifyz**

# %% [markdown]
# **Date: 26/06/24 to 26/07/24**

# %% [markdown]
# **Level 2**

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Dataset .csv')

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.tail(1)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address Locality  \
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...     Moda
#
#      Locality Verbose  Longitude   Latitude Cuisines  ...          Currency  \
# 9550  Moda, ��stanbul  29.026016  40.984776     Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 9550   Very Good   591
#
# [1 rows x 21 columns]

# %%
df.sample(1)
# Out:
#       Restaurant ID         Restaurant Name  Country Code       City  \
# 4362       18354985  Amul Ice-Cream Parlour             1  New Delhi
#
#                               Address Locality Locality Verbose  Longitude  \
# 4362  61-B, Ber Sarai, JNU, New Delhi      JNU   JNU, New Delhi  77.181182
#
#        Latitude   Cuisines  ...            Currency Has Table booking  \
# 4362  28.548978  Ice Cream  ...  Indian Rupees(Rs.)                No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 4362                  No                No                   No           1
#
#       Aggregate rating  Rating color Rating text Votes
# 4362               0.0         White   Not rated     1
#
# [1 rows x 21 columns]

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.size
# Out:
# 200571

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# **Task1:  Table Booking and Online Delivery**

# %% [markdown]
# 1)Determine the percentage of restaurants that
#  offer table booking and online delivery.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df['Has Table booking'].value_counts()
# Out:
# Has Table booking
# No     8393
# Yes    1158
# Name: count, dtype: int64

# %%
df['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
print("Table booking",round((1158/(1158+8393))*100,2),"%")
# Out:
# Table booking 12.12 %

# %%
print('Online Delivery:',round((2451/(2451+7100))*100,2),'%')
# Out:
# Online Delivery: 25.66 %

# %% [markdown]
# 2)Compare the average ratings of restaurants
#  with table booking and those without

# %%
df.head(1
      )
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df_with_table_booking = df[df['Has Table booking'] == 'Yes']
df_without_table_booking = df[df['Has Table booking'] =="No"]

# %%
print('Rows with table booking',df_with_table_booking.shape)
print('Rows without table booking',df_without_table_booking.shape)
# Out:
# Rows with table booking (1158, 21)
# Rows without table booking (8393, 21)

# %%
#average rating of Restaurants

print('Average rating of Restaurants with table booking',round(df_with_table_booking['Aggregate rating'].mean(),2))
print('Average rating of Restaurants without table booking',round(df_without_table_booking['Aggregate rating'].mean(),2))
# Out:
# Average rating of Restaurants with table booking 3.44
# Average rating of Restaurants without table booking 2.56

# %% [markdown]
# 3) Analyze the availability of online delivery
#  among restaurants with different price ranges.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
#group by price range and calculate the percentage of restaurands with online delivery
Online_Delivery_by_price_range = df.groupby(['Price range'])['Has Online delivery'].value_counts(normalize=True).unstack()*100

# %%
Online_Delivery_by_price_range.plot(kind = 'bar',stacked=True,colormap ="viridis",figsize = (10,5))
plt.xlabel('Price range')
plt.ylabel('Percentage of Restaurants with online Delivery')
plt.title('Online Delivery by Price range')
plt.grid()
plt.legend(title = 'Online Delivery',bbox_to_anchor = (1,1))
plt.show()

# %%
#the restaurants have a online delivery
Online_Delivery_yes=df[df['Has Online delivery'] == 'Yes']

Online_Delivery_counts = Online_Delivery_yes.groupby(['Price range'])['Has Online delivery'].value_counts()

# %%
Online_Delivery_counts.plot(kind = 'bar',stacked=True,colormap ="summer",figsize = (10,5),label = 'yes')
plt.xlabel('Price range')
plt.ylabel('Number of Restaurants with online Delivery')
plt.title('Online delivery availability by price range')
plt.grid()
plt.legend(title = 'Online Delivery',bbox_to_anchor = (1,1),loc = 'upper left')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# **Task 2: Price Range Analysis**

# %% [markdown]
# 1) Determine the most common price range
#  among all the restaurants.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
df['Price range'].value_counts()[1]
# Out:
# 4444

# %%
most_common = df['Price range'].mode()[0]

# %%
print('Most Common price range among all Restaurants:',most_common)
# Out:
# Most Common price range among all Restaurants: 1

# %% [markdown]
# 2) Calculate the average rating for each price
#  range.

# %%
Avg_Rating_by_price_range = df.groupby(['Price range'])['Aggregate rating'].mean().round(2)

# %%
print('Average rating for each price range:')
print(Avg_Rating_by_price_range)
# Out:
# Average rating for each price range:
# Price range
# 1    2.00
# 2    2.94
# 3    3.68
# 4    3.82
# Name: Aggregate rating, dtype: float64

# %%
plt.bar(Avg_Rating_by_price_range.index,Avg_Rating_by_price_range,color = ['skyblue','green','yellow','orange'],width = 0.5)
plt.xlabel('Price range')
plt.ylabel('Average rating')
plt.title('Average rating by price range')
plt.grid()
plt.show()

# %% [markdown]
# **Task3 : Feature Engineering**

# %% [markdown]
# 1) Extract additional features from the existing
#  columns, such as the length of the restaurant
#  name or address.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df['Restaurant Name Length'] = df['Restaurant Name'].apply(len)
df['Address Length'] = df['Address'].apply(len)

# %%
df[['Restaurant Name','Restaurant Name Length','Address','Address Length']]
# Out:
#                Restaurant Name  Restaurant Name Length  \
# 0             Le Petit Souffle                      16
# 1             Izakaya Kikufuji                      16
# 2       Heat - Edsa Shangri-La                      22
# 3                         Ooma                       4
# 4                  Sambo Kojin                      11
# ...                        ...                     ...
# 9546               Naml۱ Gurme                      11
# 9547              Ceviz A��ac۱                      12
# 9548                     Huqqa                       5
# 9549               A���k Kahve                      11
# 9550  Walter's Coffee Roastery                      24
#
#                                                 Address  Address Length
# 0     Third Floor, Century City Mall, Kalayaan Avenu...              71
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...              67
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...              56
# ...

# %% [markdown]
# 2) Create new features like "Has Table Booking"
#  or "Has Online Delivery" by encoding
#  categorical variables.

# %%
df_encoded = pd.get_dummies(df, columns=['Has Table booking', 'Has Online delivery'])

print(df_encoded.head())
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...
